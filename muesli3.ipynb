# %%
# Import some libs
import pandas as pd
import matplotlib.pyplot as plt
import openpyxl as op
import seaborn as sns

# %%
# read data
#df = pd.read_excel('data/5 - Muesli Project raw data.xlsx', skiprows=1) # remove first row

df_orders = pd.read_csv('data/5 - Muesli Project raw data - Orders.csv', skiprows=1)
df_campaigns = pd.read_csv('data/5 - Muesli Project raw data - Campaign Data.csv')
df_intern_data = pd.read_csv('data/5 - Muesli Project raw data - InternData Study.csv')
df_process_data = pd.read_csv('data/5 - Muesli Project raw data - Order Process Data.csv')

#df_process_data.head(20)

# %%
# clean up data - replace ' ' with '_'

cols = df_orders.columns.tolist()
cols = [col.replace(' ', '_') for col in cols]
df_orders.columns = cols

cols = df_campaigns.columns.tolist()
cols = [col.replace(' ', '_') for col in cols]
df_campaigns.columns = cols

cols = df_intern_data.columns.tolist()
cols = [col.replace(' ', '_') for col in cols]
df_intern_data.columns = cols

cols = df_process_data.columns.tolist()
cols = [col.replace(' ', '_') for col in cols]
df_process_data.columns = cols

#df_process_data.head(20)

# %%
# clean up - data - convert date string to datetime obj.

df_orders['Order_Date'] = pd.to_datetime(df_orders['Order_Date'], dayfirst=True, format="%d/%m/%y", infer_datetime_format=True)

df_campaigns['Arrival_Scan_Date'] = pd.to_datetime(df_campaigns['Arrival_Scan_Date'], dayfirst=True, format="%d/%m/%y", infer_datetime_format=True)

df_intern_data['Ready_to_Ship_Date'] = pd.to_datetime(df_intern_data['Ready_to_Ship_Date'], dayfirst=True, format="%d/%m/%y", infer_datetime_format=True)
df_intern_data['Pickup_Date'] = pd.to_datetime(df_intern_data['Pickup_Date'], dayfirst=True, format="%d/%m/%y", infer_datetime_format=True)

df_process_data['Order_Date'] = pd.to_datetime(df_process_data['Order_Date'], dayfirst=True, format="%d/%m/%y", infer_datetime_format=True)
df_process_data['On_Truck_Scan_Date'] = pd.to_datetime(df_process_data['On_Truck_Scan_Date'], dayfirst=True, format="%d/%m/%y", infer_datetime_format=True)

#df_process_data.head(20)

# %%
# find duplicates and remove

df_orders.drop(['Index'], axis=1, inplace=True)
df_orders.drop_duplicates(inplace=True)
#df_orders.duplicated().value_counts()

df_intern_data.drop_duplicates(inplace=True) 
#df_intern_data.duplicated().value_counts()

df_process_data.drop(['Row_ID'], axis=1, inplace=True)
df_process_data.drop_duplicates(inplace=True)
#df_process_data.duplicated().value_counts()

# %%
df_orders.head()
df_process = df_orders[['Order_ID', 'Order_Date']]

# %%
df_process.head()
# Out:
#          Order_ID Order_Date
# 0  CA-2019-121755 2019-01-16
# 1  CA-2019-118255 2019-03-11
# 2  CA-2019-169194 2019-06-20
# 3  CA-2019-111682 2019-06-17
# 4  CA-2018-135545 2018-11-24

# %%
df_process.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9993 entries, 0 to 9993
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order_ID    9993 non-null   object
#  1   Order_Date  9993 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 234.2+ KB

# %%
df_intern_data.head()
# Out:
#          Order_ID Ready_to_Ship_Date Pickup_Date
# 0  CA-2019-116540         2019-09-02  2019-09-03
# 2  CA-2019-129847         2019-09-04  2019-09-04
# 3  CA-2019-129630         2019-09-04  2019-09-04
# 4  CA-2019-106278         2019-09-05  2019-09-06
# 5  CA-2019-158099         2019-09-05  2019-09-06

# %%
#merge all dates to one dataframe
df_process = pd.merge(
    pd.DataFrame(df_process),
    pd.DataFrame(df_intern_data[["Order_ID", "Ready_to_Ship_Date", "Pickup_Date"]]),
    on='Order_ID',
    how='left')
df_process.head(30)
# Out:
#           Order_ID Order_Date Ready_to_Ship_Date Pickup_Date
# 0   CA-2019-121755 2019-01-16                NaT         NaT
# 1   CA-2019-118255 2019-03-11                NaT         NaT
# 2   CA-2019-169194 2019-06-20                NaT         NaT
# 3   CA-2019-111682 2019-06-17                NaT         NaT
# 4   CA-2018-135545 2018-11-24                NaT         NaT
# 5   CA-2020-155558 2020-10-26                NaT         NaT
# 6   CA-2019-158568 2019-08-29                NaT         NaT
# 7   US-2018-156867 2018-11-13                NaT         NaT
# 8   CA-2020-119004 2020-11-23         2020-11-30  2020-12-02
# 9   CA-2018-129476 2018-10-15                NaT         NaT
# 10  CA-2018-119697 2018-12-28                NaT         NaT
# 11  CA-2017-166191 2017-12-05                NaT         NaT
# 12  CA-2017-158274 2017-11-19                NaT         NaT
# 13  CA-2017-123260 2017-08-26                NaT         NaT
# 14  CA-2018-101007 2018-02-09                NaT         NaT
# 15  CA-2018-146262 2018-01-02                NaT         NaT
# 16  US-2020-100930 2020-04-07                NaT         NaT
# 17  CA-2019-145625 2019-09-11         2019-09-17  2019-09-18
# 18  CA-2020-163139 2020-12-01                NaT         NaT
# 19  CA-2018-155040 2018-11-10                NaT         NaT
# 20  CA-2018-155334 2018-07-30                NaT         NaT
# 21  CA-2018-130883 2018-09-26                NaT         NaT
# 22  CA-2019-110772 2019-11-20                NaT         NaT
# 23  CA-2017-164973 2017-11-04                NaT         NaT
# 24  CA-2019-162138 2019-04-23                NaT         NaT
# 25  CA-2019-129714 2019-09-01                NaT         NaT
# 26  US-2017-119137 2017-07-23                NaT         NaT
# 27  US-2017-119137 2017-07-23                NaT         NaT
# 28  CA-2018-125395 2018-06-26                NaT         NaT
# 29  US-2018-168935 2018-11-27                NaT         NaT

# %%
df_process = pd.merge(
    pd.DataFrame(df_process),
    pd.DataFrame(df_process_data[["Order_ID", "On_Truck_Scan_Date", "Ship_Mode"]]),
    on='Order_ID',
    how='left')
df_process.head(30)
# Out:
#           Order_ID Order_Date Ready_to_Ship_Date Pickup_Date  \
# 0   CA-2019-121755 2019-01-16                NaT         NaT
# 1   CA-2019-118255 2019-03-11                NaT         NaT
# 2   CA-2019-169194 2019-06-20                NaT         NaT
# 3   CA-2019-111682 2019-06-17                NaT         NaT
# 4   CA-2018-135545 2018-11-24                NaT         NaT
# 5   CA-2020-155558 2020-10-26                NaT         NaT
# 6   CA-2019-158568 2019-08-29                NaT         NaT
# 7   US-2018-156867 2018-11-13                NaT         NaT
# 8   CA-2020-119004 2020-11-23         2020-11-30  2020-12-02
# 9   CA-2018-129476 2018-10-15                NaT         NaT
# 10  CA-2018-119697 2018-12-28                NaT         NaT
# 11  CA-2017-166191 2017-12-05                NaT         NaT
# 12  CA-2017-158274 2017-11-19                NaT         NaT
# 13  CA-2017-123260 2017-08-26                NaT         NaT
# 14  CA-2018-101007 2018-02-09                NaT         NaT
# 15  CA-2018-146262 2018-01-02                NaT         NaT
# 16  US-2020-100930 2020-04-07                NaT         NaT
# 17  CA-2019-145625 2019-09-11         2019-09-17  2019-09-18
# 18  CA-2020-163139 2020-12-01                NaT         NaT
# 19  CA-2018-155040 2018-11-10                NaT         NaT
# 20  CA-2018-155334 2018-07-30                NaT         NaT
# 21  CA-2018-130883 2018-09-26                NaT         NaT
# 22  CA-2019-110772 2019-11-20                NaT         NaT
# 23  CA-2017-164973 2017-11-04                NaT         NaT
# 24  CA-2019-162138 2019-04-23                NaT         NaT
# 25  CA-2019-129714 2019-09-01                NaT         NaT
# 26  US-2017-119137 2017-07-23                NaT         NaT
# 27  US-2017-119137 2017-07-23                NaT         NaT
# 28  CA-2018-125395 2018-06-26                NaT         NaT
# 29  US-2018-168935 2018-11-27                NaT         NaT
#
#    On_Truck_Scan_Date            Ship_Mode
# 0          2019-01-23  Standard Processing
# 1          2019-03-13              Express
# 2          2019-06-26  Standard Processing
# 3          2019-06-19              Express
# 4                 NaT                  NaN
# 5          2020-11-04  Standard Processing
# 6          2019-09-04  Standard Processing
# 7                 NaT                  NaN
# 8          2020-12-02  Standard Processing
# 9                 NaT                  NaN
# 10                NaT                  NaN
# 11                NaT                  NaN
# 12                NaT                  NaN
# 13                NaT                  NaN
# 14                NaT                  NaN
# 15                NaT                  NaN
# 16         2020-04-15  Standard Processing
# 17         2019-09-18  Standard Processing
# 18         2020-12-04  Standard Processing
# 19                NaT                  NaN
# 20                NaT                  NaN
# 21                NaT                  NaN
# 22         2019-11-27  Standard Processing
# 23                NaT                  NaN
# 24         2019-05-01  Standard Processing
# 25         2019-09-04              Express
# 26                NaT                  NaN
# 27                NaT                  NaN
# 28                NaT                  NaN
# 29                NaT                  NaN

# %%
df_process.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9995 entries, 0 to 9994
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order_ID            9995 non-null   object
#  1   Order_Date          9995 non-null   datetime64[ns]
#  2   Ready_to_Ship_Date  418 non-null    datetime64[ns]
#  3   Pickup_Date         418 non-null    datetime64[ns]
#  4   On_Truck_Scan_Date  5901 non-null   datetime64[ns]
#  5   Ship_Mode           5901 non-null   object
# dtypes: datetime64[ns](4), object(2)
# memory usage: 546.6+ KB

# %%
df_process = pd.merge(
    pd.DataFrame(df_process),
    pd.DataFrame(df_campaigns[["Order_ID", "Arrival_Scan_Date"]]),
    on='Order_ID',
    how='left')
df_process.head(30)
# Out:
#           Order_ID Order_Date Ready_to_Ship_Date Pickup_Date  \
# 0   CA-2019-121755 2019-01-16                NaT         NaT
# 1   CA-2019-118255 2019-03-11                NaT         NaT
# 2   CA-2019-169194 2019-06-20                NaT         NaT
# 3   CA-2019-111682 2019-06-17                NaT         NaT
# 4   CA-2018-135545 2018-11-24                NaT         NaT
# 5   CA-2020-155558 2020-10-26                NaT         NaT
# 6   CA-2019-158568 2019-08-29                NaT         NaT
# 7   US-2018-156867 2018-11-13                NaT         NaT
# 8   CA-2020-119004 2020-11-23         2020-11-30  2020-12-02
# 9   CA-2018-129476 2018-10-15                NaT         NaT
# 10  CA-2018-119697 2018-12-28                NaT         NaT
# 11  CA-2017-166191 2017-12-05                NaT         NaT
# 12  CA-2017-158274 2017-11-19                NaT         NaT
# 13  CA-2017-123260 2017-08-26                NaT         NaT
# 14  CA-2018-101007 2018-02-09                NaT         NaT
# 15  CA-2018-146262 2018-01-02                NaT         NaT
# 16  US-2020-100930 2020-04-07                NaT         NaT
# 17  CA-2019-145625 2019-09-11         2019-09-17  2019-09-18
# 18  CA-2020-163139 2020-12-01                NaT         NaT
# 19  CA-2018-155040 2018-11-10                NaT         NaT
# 20  CA-2018-155334 2018-07-30                NaT         NaT
# 21  CA-2018-130883 2018-09-26                NaT         NaT
# 22  CA-2019-110772 2019-11-20                NaT         NaT
# 23  CA-2017-164973 2017-11-04                NaT         NaT
# 24  CA-2019-162138 2019-04-23                NaT         NaT
# 25  CA-2019-129714 2019-09-01                NaT         NaT
# 26  US-2017-119137 2017-07-23                NaT         NaT
# 27  US-2017-119137 2017-07-23                NaT         NaT
# 28  CA-2018-125395 2018-06-26                NaT         NaT
# 29  US-2018-168935 2018-11-27                NaT         NaT
#
#    On_Truck_Scan_Date            Ship_Mode Arrival_Scan_Date
# 0          2019-01-23  Standard Processing               NaT
# 1          2019-03-13              Express               NaT
# 2          2019-06-26  Standard Processing               NaT
# 3          2019-06-19              Express               NaT
# 4                 NaT                  NaN               NaT
# 5          2020-11-04  Standard Processing               NaT
# 6          2019-09-04  Standard Processing               NaT
# 7                 NaT                  NaN               NaT
# 8          2020-12-02  Standard Processing               NaT
# 9                 NaT                  NaN               NaT
# 10                NaT                  NaN               NaT
# 11                NaT                  NaN               NaT
# 12                NaT                  NaN               NaT
# 13                NaT                  NaN               NaT
# 14                NaT                  NaN               NaT
# 15                NaT                  NaN               NaT
# 16         2020-04-15  Standard Processing               NaT
# 17         2019-09-18  Standard Processing        2019-09-23
# 18         2020-12-04  Standard Processing               NaT
# 19                NaT                  NaN               NaT
# 20                NaT                  NaN               NaT
# 21                NaT                  NaN               NaT
# 22         2019-11-27  Standard Processing               NaT
# 23                NaT                  NaN               NaT
# 24         2019-05-01  Standard Processing        2019-05-06
# 25         2019-09-04              Express               NaT
# 26                NaT                  NaN               NaT
# 27                NaT                  NaN               NaT
# 28                NaT                  NaN               NaT
# 29                NaT                  NaN               NaT

# %%
df_process.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9995 entries, 0 to 9994
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order_ID            9995 non-null   object
#  1   Order_Date          9995 non-null   datetime64[ns]
#  2   Ready_to_Ship_Date  418 non-null    datetime64[ns]
#  3   Pickup_Date         418 non-null    datetime64[ns]
#  4   On_Truck_Scan_Date  5901 non-null   datetime64[ns]
#  5   Ship_Mode           5901 non-null   object
#  6   Arrival_Scan_Date   668 non-null    datetime64[ns]
# dtypes: datetime64[ns](5), object(2)
# memory usage: 624.7+ KB

# %%
#Calculate durations between each dates and add them to our new dataframe

df_process['Order_Ship_Duration'] =  df_process['Ready_to_Ship_Date'] - df_process['Order_Date']
df_process['Ship_Pickup_Duration'] =  df_process['Pickup_Date'] - df_process['Ready_to_Ship_Date']
df_process['Pickup_Truck_Duration'] =  df_process['On_Truck_Scan_Date'] - df_process['Pickup_Date']
df_process['Truck_Arrival_Duration'] =  df_process['Arrival_Scan_Date'] - df_process['On_Truck_Scan_Date']

df_process.head(30)
# Out:
#           Order_ID Order_Date Ready_to_Ship_Date Pickup_Date  \
# 0   CA-2019-121755 2019-01-16                NaT         NaT
# 1   CA-2019-118255 2019-03-11                NaT         NaT
# 2   CA-2019-169194 2019-06-20                NaT         NaT
# 3   CA-2019-111682 2019-06-17                NaT         NaT
# 4   CA-2018-135545 2018-11-24                NaT         NaT
# 5   CA-2020-155558 2020-10-26                NaT         NaT
# 6   CA-2019-158568 2019-08-29                NaT         NaT
# 7   US-2018-156867 2018-11-13                NaT         NaT
# 8   CA-2020-119004 2020-11-23         2020-11-30  2020-12-02
# 9   CA-2018-129476 2018-10-15                NaT         NaT
# 10  CA-2018-119697 2018-12-28                NaT         NaT
# 11  CA-2017-166191 2017-12-05                NaT         NaT
# 12  CA-2017-158274 2017-11-19                NaT         NaT
# 13  CA-2017-123260 2017-08-26                NaT         NaT
# 14  CA-2018-101007 2018-02-09                NaT         NaT
# 15  CA-2018-146262 2018-01-02                NaT         NaT
# 16  US-2020-100930 2020-04-07                NaT         NaT
# 17  CA-2019-145625 2019-09-11         2019-09-17  2019-09-18
# 18  CA-2020-163139 2020-12-01                NaT         NaT
# 19  CA-2018-155040 2018-11-10                NaT         NaT
# 20  CA-2018-155334 2018-07-30                NaT         NaT
# 21  CA-2018-130883 2018-09-26                NaT         NaT
# 22  CA-2019-110772 2019-11-20                NaT         NaT
# 23  CA-2017-164973 2017-11-04                NaT         NaT
# 24  CA-2019-162138 2019-04-23                NaT         NaT
# 25  CA-2019-129714 2019-09-01                NaT         NaT
# 26  US-2017-119137 2017-07-23                NaT         NaT
# 27  US-2017-119137 2017-07-23                NaT         NaT
# 28  CA-2018-125395 2018-06-26                NaT         NaT
# 29  US-2018-168935 2018-11-27                NaT         NaT
#
#    On_Truck_Scan_Date            Ship_Mode Arrival_Scan_Date  \
# 0          2019-01-23  Standard Processing               NaT
# 1          2019-03-13              Express               NaT
# 2          2019-06-26  Standard Processing               NaT
# 3          2019-06-19              Express               NaT
# 4                 NaT                  NaN               NaT
# 5          2020-11-04  Standard Processing               NaT
# 6          2019-09-04  Standard Processing               NaT
# 7                 NaT                  NaN               NaT
# 8          2020-12-02  Standard Processing               NaT
# 9                 NaT                  NaN               NaT
# 10                NaT                  NaN               NaT
# 11                NaT                  NaN               NaT
# 12                NaT                  NaN               NaT
# 13                NaT                  NaN               NaT
# 14                NaT                  NaN               NaT
# 15                NaT                  NaN               NaT
# 16         2020-04-15  Standard Processing               NaT
# 17         2019-09-18  Standard Processing        2019-09-23
# 18         2020-12-04  Standard Processing               NaT
# 19                NaT                  NaN               NaT
# 20                NaT                  NaN               NaT
# 21                NaT                  NaN               NaT
# 22         2019-11-27  Standard Processing               NaT
# 23                NaT                  NaN               NaT
# 24         2019-05-01  Standard Processing        2019-05-06
# 25         2019-09-04              Express               NaT
# 26                NaT                  NaN               NaT
# 27                NaT                  NaN               NaT
# 28                NaT                  NaN               NaT
# 29                NaT                  NaN               NaT
#
#    Order_Ship_Duration Ship_Pickup_Duration Pickup_Truck_Duration  \
# 0                  NaT                  NaT                   NaT
# 1                  NaT                  NaT                   NaT
# 2                  NaT                  NaT                   NaT
# 3                  NaT                  NaT                   NaT
# 4                  NaT                  NaT                   NaT
# 5                  NaT                  NaT                   NaT
# 6                  NaT                  NaT                   NaT
# 7                  NaT                  NaT                   NaT
# 8               7 days               2 days                0 days
# 9                  NaT                  NaT                   NaT
# 10                 NaT                  NaT                   NaT
# 11                 NaT                  NaT                   NaT
# 12                 NaT                  NaT                   NaT
# 13                 NaT                  NaT                   NaT
# 14                 NaT                  NaT                   NaT
# 15                 NaT                  NaT                   NaT
# 16                 NaT                  NaT                   NaT
# 17              6 days               1 days                0 days
# 18                 NaT                  NaT                   NaT
# 19                 NaT                  NaT                   NaT
# 20                 NaT                  NaT                   NaT
# 21                 NaT                  NaT                   NaT
# 22                 NaT                  NaT                   NaT
# 23                 NaT                  NaT                   NaT
# 24                 NaT                  NaT                   NaT
# 25                 NaT                  NaT                   NaT
# 26                 NaT                  NaT                   NaT
# 27                 NaT                  NaT                   NaT
# 28                 NaT                  NaT                   NaT
# 29                 NaT                  NaT                   NaT
#
#    Truck_Arrival_Duration
# 0                     NaT
# 1                     NaT
# 2                     NaT
# 3                     NaT
# 4                     NaT
# 5                     NaT
# 6                     NaT
# 7                     NaT
# 8                     NaT
# 9                     NaT
# 10                    NaT
# 11                    NaT
# 12                    NaT
# 13                    NaT
# 14                    NaT
# 15                    NaT
# 16                    NaT
# 17                 5 days
# 18                    NaT
# 19                    NaT
# 20                    NaT
# 21                    NaT
# 22                    NaT
# 23                    NaT
# 24                 5 days
# 25                    NaT
# 26                    NaT
# 27                    NaT
# 28                    NaT
# 29                    NaT

# %%
df_process.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9995 entries, 0 to 9994
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Order_ID                9995 non-null   object
#  1   Order_Date              9995 non-null   datetime64[ns]
#  2   Ready_to_Ship_Date      418 non-null    datetime64[ns]
#  3   Pickup_Date             418 non-null    datetime64[ns]
#  4   On_Truck_Scan_Date      5901 non-null   datetime64[ns]
#  5   Ship_Mode               5901 non-null   object
#  6   Arrival_Scan_Date       668 non-null    datetime64[ns]
#  7   Order_Ship_Duration     418 non-null    timedelta64[ns]
#  8   Ship_Pickup_Duration    418 non-null    timedelta64[ns]
#  9   Pickup_Truck_Duration   418 non-null    timedelta64[ns]
#  10  Truck_Arrival_Duration  668 non-null    timedelta64[ns]
# dtypes: datetime64[ns](5), object(2), timedelta64[ns](4)
# memory usage: 937.0+ KB

# %%
#we want to see if the duration of warehouse processing influences our profit

df_process_profit = pd.merge(
    pd.DataFrame(df_process),
    pd.DataFrame(df_orders[["Order_ID", "Profit"]]),
    on='Order_ID',
    how='left')
df_process_profit
# Out:
#              Order_ID Order_Date Ready_to_Ship_Date Pickup_Date  \
# 0      CA-2019-121755 2019-01-16                NaT         NaT
# 1      CA-2019-121755 2019-01-16                NaT         NaT
# 2      CA-2019-118255 2019-03-11                NaT         NaT
# 3      CA-2019-118255 2019-03-11                NaT         NaT
# 4      CA-2019-169194 2019-06-20                NaT         NaT
# ...               ...        ...                ...         ...
# 29898  CA-2020-121559 2020-06-01                NaT         NaT
# 29899  CA-2020-121559 2020-06-01                NaT         NaT
# 29900  CA-2020-121559 2020-06-01                NaT         NaT
# 29901  CA-2020-121559 2020-06-01                NaT         NaT
# 29902  CA-2020-121559 2020-06-01                NaT         NaT
#
#       On_Truck_Scan_Date            Ship_Mode Arrival_Scan_Date  \
# 0             2019-01-23  Standard Processing               NaT
# 1             2019-01-23  Standard Processing               NaT
# 2             2019-03-13              Express               NaT
# 3             2019-03-13              Express               NaT
# 4             2019-06-26  Standard Processing               NaT
# ...                  ...                  ...               ...
# 29898         2020-06-05  Standard Processing               NaT
# 29899         2020-06-05  Standard Processing               NaT
# 29900         2020-06-05  Standard Processing               NaT
# 29901         2020-06-05  Standard Processing               NaT
# 29902         2020-06-05  Standard Processing               NaT
#
#       Order_Ship_Duration Ship_Pickup_Duration Pickup_Truck_Duration  \
# 0                     NaT                  NaT                   NaT
# 1                     NaT                  NaT                   NaT
# 2                     NaT                  NaT                   NaT
# 3                     NaT                  NaT                   NaT
# 4                     NaT                  NaT                   NaT
# ...                   ...                  ...                   ...
# 29898                 NaT                  NaT                   NaT
# 29899                 NaT                  NaT                   NaT
# 29900                 NaT                  NaT                   NaT
# 29901                 NaT                  NaT                   NaT
# 29902                 NaT                  NaT                   NaT
#
#       Truck_Arrival_Duration    Profit
# 0                        NaT   11.7741
# 1                        NaT    4.2224
# 2                        NaT   19.7714
# 3                        NaT    8.2062
# 4                        NaT    4.9500
# ...                      ...       ...
# 29898                    NaT   15.9543
# 29899                    NaT   14.7593
# 29900                    NaT  793.7160
# 29901                    NaT    8.6900
# 29902                    NaT  539.2464
#
# [29903 rows x 12 columns]

# %%
df_process_profit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29903 entries, 0 to 29902
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Order_ID                29903 non-null  object
#  1   Order_Date              29903 non-null  datetime64[ns]
#  2   Ready_to_Ship_Date      1220 non-null   datetime64[ns]
#  3   Pickup_Date             1220 non-null   datetime64[ns]
#  4   On_Truck_Scan_Date      17529 non-null  datetime64[ns]
#  5   Ship_Mode               17529 non-null  object
#  6   Arrival_Scan_Date       2056 non-null   datetime64[ns]
#  7   Order_Ship_Duration     1220 non-null   timedelta64[ns]
#  8   Ship_Pickup_Duration    1220 non-null   timedelta64[ns]
#  9   Pickup_Truck_Duration   1220 non-null   timedelta64[ns]
#  10  Truck_Arrival_Duration  2056 non-null   timedelta64[ns]
#  11  Profit                  29903 non-null  float64
# dtypes: datetime64[ns](5), float64(1), object(2), timedelta64[ns](4)
# memory usage: 3.0+ MB

# %%
df_process_profit.drop_duplicates(inplace=True)

# %%
df_process_profit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9994 entries, 0 to 29882
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Order_ID                9994 non-null   object
#  1   Order_Date              9994 non-null   datetime64[ns]
#  2   Ready_to_Ship_Date      418 non-null    datetime64[ns]
#  3   Pickup_Date             418 non-null    datetime64[ns]
#  4   On_Truck_Scan_Date      5901 non-null   datetime64[ns]
#  5   Ship_Mode               5901 non-null   object
#  6   Arrival_Scan_Date       668 non-null    datetime64[ns]
#  7   Order_Ship_Duration     418 non-null    timedelta64[ns]
#  8   Ship_Pickup_Duration    418 non-null    timedelta64[ns]
#  9   Pickup_Truck_Duration   418 non-null    timedelta64[ns]
#  10  Truck_Arrival_Duration  668 non-null    timedelta64[ns]
#  11  Profit                  9994 non-null   float64
# dtypes: datetime64[ns](5), float64(1), object(2), timedelta64[ns](4)
# memory usage: 1015.0+ KB

# %%
df_process_profit.query("Order_Ship_Duration != 'NaT'", inplace=True)
df_process_profit
# Out:
#              Order_ID Order_Date Ready_to_Ship_Date Pickup_Date  \
# 25     CA-2020-119004 2020-11-23         2020-11-30  2020-12-02
# 26     CA-2020-119004 2020-11-23         2020-11-30  2020-12-02
# 27     CA-2020-119004 2020-11-23         2020-11-30  2020-12-02
# 47     CA-2019-145625 2019-09-11         2019-09-17  2019-09-18
# 48     CA-2019-145625 2019-09-11         2019-09-17  2019-09-18
# ...               ...        ...                ...         ...
# 28231  CA-2020-152142 2020-11-14         2020-11-16  2020-11-18
# 28300  US-2019-134488 2019-09-24         2019-10-01  2019-10-02
# 28897  CA-2020-103499 2020-11-20         2020-11-24  2020-11-25
# 29757  US-2020-165456 2020-11-30         2020-12-03  2020-12-04
# 29801  US-2020-109610 2020-11-25         2020-11-30  2020-12-02
#
#       On_Truck_Scan_Date            Ship_Mode Arrival_Scan_Date  \
# 25            2020-12-02  Standard Processing               NaT
# 26            2020-12-02  Standard Processing               NaT
# 27            2020-12-02  Standard Processing               NaT
# 47            2019-09-18  Standard Processing        2019-09-23
# 48            2019-09-18  Standard Processing        2019-09-23
# ...                  ...                  ...               ...
# 28231         2020-11-18  Standard Processing               NaT
# 28300         2019-10-02  Standard Processing               NaT
# 28897         2020-11-25  Standard Processing               NaT
# 29757         2020-12-04              Express               NaT
# 29801         2020-12-02  Standard Processing               NaT
#
#       Order_Ship_Duration Ship_Pickup_Duration Pickup_Truck_Duration  \
# 25                 7 days               2 days                0 days
# 26                 7 days               2 days                0 days
# 27                 7 days               2 days                0 days
# 47                 6 days               1 days                0 days
# 48                 6 days               1 days                0 days
# ...                   ...                  ...                   ...
# 28231              2 days               2 days                0 days
# 28300              7 days               1 days                0 days
# 28897              4 days               1 days                0 days
# 29757              3 days               1 days                0 days
# 29801              5 days               2 days                0 days
#
#       Truck_Arrival_Duration    Profit
# 25                       NaT   17.6016
# 26                       NaT    2.0994
# 27                       NaT    1.0738
# 47                    5 days  636.0003
# 48                    5 days    3.5767
# ...                      ...       ...
# 28231                    NaT   28.1372
# 28300                    NaT  -13.3176
# 28897                    NaT  -23.5764
# 29757                    NaT  -15.4188
# 29801                    NaT  168.4704
#
# [418 rows x 12 columns]

# %%
#We convert the days into integers (Why does .dt.days not work here?)

df_process_profit['Order_Ship_Duration'] = df_process_profit['Order_Ship_Duration'].astype('int')
df_process_profit
# Out:
#              Order_ID Order_Date Ready_to_Ship_Date Pickup_Date  \
# 25     CA-2020-119004 2020-11-23         2020-11-30  2020-12-02
# 26     CA-2020-119004 2020-11-23         2020-11-30  2020-12-02
# 27     CA-2020-119004 2020-11-23         2020-11-30  2020-12-02
# 47     CA-2019-145625 2019-09-11         2019-09-17  2019-09-18
# 48     CA-2019-145625 2019-09-11         2019-09-17  2019-09-18
# ...               ...        ...                ...         ...
# 28231  CA-2020-152142 2020-11-14         2020-11-16  2020-11-18
# 28300  US-2019-134488 2019-09-24         2019-10-01  2019-10-02
# 28897  CA-2020-103499 2020-11-20         2020-11-24  2020-11-25
# 29757  US-2020-165456 2020-11-30         2020-12-03  2020-12-04
# 29801  US-2020-109610 2020-11-25         2020-11-30  2020-12-02
#
#       On_Truck_Scan_Date            Ship_Mode Arrival_Scan_Date  \
# 25            2020-12-02  Standard Processing               NaT
# 26            2020-12-02  Standard Processing               NaT
# 27            2020-12-02  Standard Processing               NaT
# 47            2019-09-18  Standard Processing        2019-09-23
# 48            2019-09-18  Standard Processing        2019-09-23
# ...                  ...                  ...               ...
# 28231         2020-11-18  Standard Processing               NaT
# 28300         2019-10-02  Standard Processing               NaT
# 28897         2020-11-25  Standard Processing               NaT
# 29757         2020-12-04              Express               NaT
# 29801         2020-12-02  Standard Processing               NaT
#
#        Order_Ship_Duration Ship_Pickup_Duration Pickup_Truck_Duration  \
# 25         604800000000000               2 days                0 days
# 26         604800000000000               2 days                0 days
# 27         604800000000000               2 days                0 days
# 47         518400000000000               1 days                0 days
# 48         518400000000000               1 days                0 days
# ...                    ...                  ...                   ...
# 28231      172800000000000               2 days                0 days
# 28300      604800000000000               1 days                0 days
# 28897      345600000000000               1 days                0 days
# 29757      259200000000000               1 days                0 days
# 29801      432000000000000               2 days                0 days
#
#       Truck_Arrival_Duration    Profit
# 25                       NaT   17.6016
# 26                       NaT    2.0994
# 27                       NaT    1.0738
# 47                    5 days  636.0003
# 48                    5 days    3.5767
# ...                      ...       ...
# 28231                    NaT   28.1372
# 28300                    NaT  -13.3176
# 28897                    NaT  -23.5764
# 29757                    NaT  -15.4188
# 29801                    NaT  168.4704
#
# [418 rows x 12 columns]

# %%
fig, ax = plt.subplots()
plt.scatter(df_process_profit['Order_Ship_Duration'], df_process_profit['Profit'])
#ax.set_xticklabels(['Express', 'Standard'])
# plt.suptitle('Delivery Duration')
# plt.ylabel('Days')
plt.show()

# %%
sns.pairplot(df_process_profit)

# %%
df_orders.head()
# Out:
#          Order_ID Order_Date       Ship_mode Customer_ID    Customer_Name  \
# 0  CA-2019-121755 2019-01-16    Second Class    EH-13945    Eric Hoffmann
# 1  CA-2019-118255 2019-03-11     First Class    ON-18715    Odella Nelson
# 2  CA-2019-169194 2019-06-20  Standard Class    LH-16900   Lena Hernandez
# 3  CA-2019-111682 2019-06-17     First Class    TB-21055  Ted Butterfield
# 4  CA-2018-135545 2018-11-24  Standard Class    KM-16720     Kunst Miller
#
#   Origin_Channel Country/Region         City       State  Postal_Code  \
# 0          Email  United States  Los Angeles  California      90049.0
# 1          Sales  United States        Eagan   Minnesota      55122.0
# 2          Email  United States        Dover    Delaware      19901.0
# 3          Email  United States         Troy    New York      12180.0
# 4          Email  United States  Los Angeles  California      90004.0
#
#     Region                 Category Sub-Category       Product_ID  Sales  \
# 0     West  Special Projects Muesil  Gluten Free  TEC-AC-10003027  90.57
# 1  Central  Special Projects Muesil  Gluten Free  TEC-AC-10000171  45.98
# 2     East  Special Projects Muesil  Gluten Free  TEC-AC-10002167  45.00
# 3     East  Special Projects Muesil  Gluten Free  TEC-AC-10002167  30.00
# 4     West  Special Projects Muesil  Gluten Free  TEC-AC-10004633  13.98
#
#    Quantity  Discount   Profit
# 0         3       0.0  11.7741
# 1         2       0.0  19.7714
# 2         3       0.0   4.9500
# 3         2       0.0   3.3000
# 4         2       0.0   6.1512

# %%
df_num_deliveries = df_orders[['Order_Date', 'Quantity']]
df_num_deliveries
# Out:
#      Order_Date  Quantity
# 0    2019-01-16         3
# 1    2019-03-11         2
# 2    2019-06-20         3
# 3    2019-06-17         2
# 4    2018-11-24         2
# ...         ...       ...
# 9989 2019-07-25         4
# 9990 2018-09-13         3
# 9991 2018-10-10         3
# 9992 2019-03-15         5
# 9993 2020-06-01         6
#
# [9993 rows x 2 columns]

# %%
x = df_num_deliveries.groupby(df_num_deliveries['Order_Date'].dt.to_period('Y'))['Quantity'].agg(['sum', 'mean', 'max'])
x
# Out:
#               sum      mean  max
# Order_Date
# 2017         7579  3.804719   14
# 2018         7979  3.795909   14
# 2019         9837  3.802474   14
# 2020        12476  3.766908   14

# %%
# Out:
#               sum      mean  max
# Order_Date
# 2017         7579  3.804719   14
# 2018         7979  3.795909   14
# 2019         9837  3.802474   14
# 2020        12476  3.766908   14

# %%
fig, ax = plt.subplots()
plt.bar(x['Order_Date'], height= 'sum')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/nf_base/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///Users/deming/opt/anaconda3/envs/nf_base/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///Users/deming/opt/anaconda3/envs/nf_base/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///Users/deming/opt/anaconda3/envs/nf_base/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File ~/opt/anaconda3/envs/nf_base/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/envs/nf_base/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Order_Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/deming/neuefische/Muesli-Sebastian-Deming/muesli3.ipynb Cell 28' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/deming/neuefische/Muesli-Sebastian-Deming/muesli3.ipynb#ch0000044?line=0'>1</a> fig, ax = plt.subplots()
# ----> <a href='vscode-notebook-cell:/Users/deming/neuefische/Muesli-Sebastian-Deming/muesli3.ipynb#ch0000044?line=1'>2</a> plt.bar(x['Order_Date'], height= 'sum')
#
# File ~/opt/anaconda3/envs/nf_base/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    <a href='file:///Users/deming/opt/anaconda3/envs/nf_base/lib/python3.9/site-packages/pandas/core/frame.py?line=3502'>3503</a> if self.columns.nlevels > 1:
#    <a href='file:///Users/deming/opt/anaconda3/envs/nf_base/lib/python3.9/site-packages/pandas/core/frame.py?line=3503'>3504</a>     return self._getitem_multilevel(key)
# -> <a href='file:///Users/deming/opt/anaconda3/envs/nf_base/lib/python3.9/site-packages/pandas/core/frame.py?line=3504'>3505</a> indexer = self.columns.get_loc(key)
#    <a href='file:///Users/deming/opt/anaconda3/envs/nf_base/lib/python3.9/site-packages/pandas/core/frame.py?line=3505'>3506</a> if is_integer(indexer):
#    <a href='file:///Users/deming/opt/anaconda3/envs/nf_base/lib/python3.9/site-packages/pandas/core/frame.py?line=3506'>3507</a>     indexer = [indexer]
#
# File ~/opt/anaconda3/envs/nf_base/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///Users/deming/opt/anaconda3/envs/nf_base/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///Users/deming/opt/anaconda3/envs/nf_base/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
# -> <a href='file:///Users/deming/opt/anaconda3/envs/nf_base/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3622'>3623</a>     raise KeyError(key) from err
#    <a href='file:///Users/deming/opt/anaconda3/envs/nf_base/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3623'>3624</a> except TypeError:
#    <a href='file:///Users/deming/opt/anaconda3/envs/nf_base/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3624'>3625</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///Users/deming/opt/anaconda3/envs/nf_base/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3625'>3626</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///Users/deming/opt/anaconda3/envs/nf_base/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3626'>3627</a>     #  the TypeError.
#    <a href='file:///Users/deming/opt/anaconda3/envs/nf_base/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3627'>3628</a>     self._check_indexing_error(key)
#
# KeyError: 'Order_Date'
